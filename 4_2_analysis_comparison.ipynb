# %% [markdown]
# # Import

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('assets/comparison_analysis.csv')

print(df.shape)
# Out:
# (11, 5)

# %%
df = pd.read_excel('filtered/comparison.xlsx')

print(df.shape)
# Out:
# (7, 6)

# %% [markdown]
# # Counter

# %%
df.groupby('participant_id').aggregate({'id': 'count'}).sort_values('id', ascending=False)
# Out:
#                   id
# participant_id
# Monica Pizzella    4
# Sabrina Varriano   2
# Valentina          1

# %% [markdown]
# # Time

# %%
ax = df.groupby('date').aggregate({'id': 'count'}).plot(marker='o')
plt.xlabel('Date')
plt.ylabel('Utilizzo')
plt.xticks(rotation=45, ha='right')
plt.legend([])
plt.show()
